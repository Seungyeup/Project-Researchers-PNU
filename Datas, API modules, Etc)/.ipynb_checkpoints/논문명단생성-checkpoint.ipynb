# %% [markdown]
#  대학, 학과, 전공, 성명, 풀네임, 년도, 논문명, 저널명, Status, J-Status, J-DB, DT-P, DT-S, DOI
#
#  -?>J-DB: S,W,Others

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame as df
from openpyxl import load_workbook

pip_list = pd.read_excel("PIP_ALL.xlsx")
scopus_list = pd.read_excel("temp_scopus_all.xlsx")
researcher_list = pd.read_excel("저자test1.xlsx")

#key는 저자명 -> PIP 순회, SCOPUS순회

nonmun_list = df(columns=['대학','학과','전공','성명','풀네임','년도','논문명','저널명','Status','J-Status','J-DB','DT-P','DT-S','DOI'])

# %%
num_cnt=0
for res in researcher_list['성명'].tolist():
    for pip_num in range(0,len(pip_list)):      # 먼저 PIP 기준으로 검색하는데
        if pip_list['성명'].loc[pip_num]==res:  # 해당 ROW성명이 저자와 일치한다면
            # 정보 일단 당겨오기
            nonmun_list.loc[num_cnt] = [ 
                pip_list['대학'].loc[pip_num], # 대학
                pip_list['학과'].loc[pip_num], # 학과
                pip_list['전공'].loc[pip_num], # 전공
                pip_list['성명'].loc[pip_num], # 성명
                None, #pip_list['대학'].loc[pip_num], # 풀네임
                None, #pip_list['대학'].loc[pip_num], # 년도
                pip_list['제목'].loc[pip_num], # 논문명
                None, #pip_list['대학'].loc[pip_num], # 저널명
                "P-only", # Status
                None, #pip_list['대학'].loc[pip_num], # J-Status
                None, #pip_list['대학'].loc[pip_num], # J-DB
                None, #pip_list['대학'].loc[pip_num], # DT-P
                None, #pip_list['대학'].loc[pip_num], # DT-S
                None, #pip_list['대학'].loc[pip_num]  # DOI
            ]
            if pip_list['제목'].loc[pip_num] in scopus_list['논문제목'].tolist():
                nonmun_list['Status'].loc[num_cnt] = "Both"
        num_cnt += 1
    for scopus_num in range(0,len(scopus_list)):
        if scopus_list['성명'].loc[scopus_num]==res:
            if scopus_list['논문제목'].loc[scopus_num] not in nonmun_list['논문명'].tolist():
                nonmun_list.loc[num_cnt] = [ 
                None, #pip_list['대학'].loc[pip_num], # 대학
                None, #pip_list['학과'].loc[pip_num], # 학과
                None, #pip_list['전공'].loc[pip_num], # 전공
                scopus_list['성명'].loc[scopus_num], # 성명
                None, #pip_list['대학'].loc[pip_num], # 풀네임
                None, #pip_list['대학'].loc[pip_num], # 년도
                scopus_list['논문제목'].loc[scopus_num], # 논문명
                None, #pip_list['대학'].loc[pip_num], # 저널명
                "S-only", # Status
                None, #pip_list['대학'].loc[pip_num], # J-Status
                None, #pip_list['대학'].loc[pip_num], # J-DB
                None, #pip_list['대학'].loc[pip_num], # DT-P
                None, #pip_list['대학'].loc[pip_num], # DT-S
                None, #pip_list['대학'].loc[pip_num]  # DOI
            ]
        num_cnt += 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-1cfa234e527f> in <module>
#      30                 None, #pip_list['학과'].loc[pip_num], # 학과
#      31                 None, #pip_list['전공'].loc[pip_num], # 전공
# ---> 32                 Scopus_list['성명'].loc[scopus_num], # 성명
#      33                 None, #pip_list['대학'].loc[pip_num], # 풀네임
#      34                 None, #pip_list['대학'].loc[pip_num], # 년도
#
# NameError: name 'Scopus_list' is not defined

# %%
nonmun_list
# Out:
#               대학         학과   전공   성명   풀네임    년도  \
# 43416   생명자원과학대학  동물생명자원과학과  NaN  김병우  None  None
# 43634   생명자원과학대학  동물생명자원과학과  NaN  김병우  None  None
# 43635   생명자원과학대학  동물생명자원과학과  NaN  김병우  None  None
# 43779   생명자원과학대학  동물생명자원과학과  NaN  김병우  None  None
# 43841   생명자원과학대학  동물생명자원과학과  NaN  김병우  None  None
# ...          ...        ...  ...  ...   ...   ...
# 495831  생명자원과학대학  동물생명자원과학과  NaN  김명후  None  None
# 495832  생명자원과학대학  동물생명자원과학과  NaN  김명후  None  None
# 496539  생명자원과학대학  동물생명자원과학과  NaN  김명후  None  None
# 501626  생명자원과학대학  동물생명자원과학과  NaN  김명후  None  None
# 506717  생명자원과학대학  동물생명자원과학과  NaN  김명후  None  None
#
#                                                       논문명   저널명  Status  \
# 43416   Growth curve estimates for wither height, hip ...  None  P-only
# 43634                       경남지방 한우의 경락가격에 관여하는요인별 기여도 분석  None  P-only
# 43635   Isolation of endo-1,4-beta-D-glucanase produci...  None  P-only
# 43779   Analysis of environmental effects affecting re...  None  P-only
# 43841   Multiple Regression Analysis to Estimate the U...  None  P-only
# ...                                                   ...   ...     ...
# 495831  Cigarette Smoke Induces Intestinal Inflammatio...  None  P-only
# 495832            고온 스트레스 영향에 따른 홀스타인종 젖소의 반추위내 미생물 균총 변화  None  P-only
# 496539  The effect of heat stress on frame switch spli...  None    Both
# 501626  Differential food protein-induced inflammatory...  None    Both
# 506717  Intestinal microbes direct CX(3)CR1(+) cells t...  None  P-only
#
#        J-Status  J-DB  DT-P  DT-S   DOI
# 43416      None  None  None  None  None
# 43634      None  None  None  None  None
# 43635      None  None  None  None  None
# 43779      None  None  None  None  None
# 43841      None  None  None  None  None
# ...         ...   ...   ...   ...   ...
# 495831     None  None  None  None  None
# 495832     None  None  None  None  None
# 496539     None  None  None  None  None
# 501626     None  None  None  None  None
# 506717     None  None  None  None  None
#
# [279 rows x 14 columns]
