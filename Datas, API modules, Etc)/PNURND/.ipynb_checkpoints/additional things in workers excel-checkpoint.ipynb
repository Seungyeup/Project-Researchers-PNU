# %%
import pandas as pd
import numpy as np
from pandas import DataFrame as df
from openpyxl import load_workbook
import math
from tqdm import tqdm,trange

pd.options.display.float_format = '{:.0f}'.format
pd.options.display.max_columns = None

workers_list = pd.read_excel("작업용엑셀(2020.06.08).xlsx")
authors = pd.read_excel("저자리스트(AUID 최신 2020.06.08).xlsx")

# %%
workers_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42762 entries, 0 to 42761
# Data columns (total 40 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  42762 non-null  int64
#  1   대학          42762 non-null  object
#  2   학과          42762 non-null  object
#  3   전공          17793 non-null  object
#  4   재직여부        42762 non-null  object
#  5   성명          42762 non-null  object
#  6   교번          42762 non-null  int64
#  7   풀네임         35915 non-null  object
#  8   Year        42762 non-null  int64
#  9   Title       42762 non-null  object
#  10  Source      42762 non-null  object
#  11  Status      42762 non-null  object
#  12  DB          22321 non-null  object
#  13  논문구분        37723 non-null  object
#  14  학술지색인       22321 non-null  object
#  15  학진등재여부      17133 non-null  object
#  16  학진등재후보      1277 non-null   object
#  17  PNU-ID      39424 non-null  object
#  18  DT(P)       37723 non-null  object
#  19  DT(S)       14494 non-null  object
#  20  DOI         14025 non-null  object
#  21  EID         14494 non-null  object
#  22  임용일자        42762 non-null  object
#  23  퇴직일자        5125 non-null   float64
#  24  공동연구자수      37723 non-null  float64
#  25  권           36644 non-null  object
#  26  호           31818 non-null  object
#  27  페이지         37715 non-null  object
#  28  ISSN        37233 non-null  object
#  29  학술단체명       37723 non-null  object
#  30  국내외구분       37723 non-null  object
#  31  학문분야        37686 non-null  object
#  32  연구원구분       37722 non-null  object
#  33  책임구분        37723 non-null  object
#  34  과제번호(차수)    17822 non-null  object
#  35  과제번호        17818 non-null  object
#  36  연구과제명       17818 non-null  object
#  37  수행기관        15148 non-null  object
#  38  지원기관        19938 non-null  object
#  39  지원금액        3908 non-null   float64
# dtypes: float64(3), int64(3), object(34)
# memory usage: 13.1+ MB

# %%
research_list_0610 = df(columns=['대학','학과','전공','재직여부','성명','교번','풀네임',
                            # au-id추가
                            'AU-ID'
                            ,'Year','Title','Source','Status','DB',
                            #추가요청
                            "논문구분",
                            "학술지색인",
                            "학진등재여부",
                            "학진등재후보",
                            #추가 필드
                           'PNU-ID',
                           'DT(P)',
                           'DT(S)',
                           'DOI',
                           'EID',
                           '임용일자',
                           '퇴직일자',
                            #추가요청2
                            '공동연구자수',
                            '권',
                            '호',
                            '페이지',
                            'ISSN',
                            '학술단체명',
                            '국내외구분',
                            '학문분야',
                            '연구원구분',
                            '책임구분',
                            '과제번호(차수)',
                            '과제번호',
                            '연구과제명',
                            '수행기관',
                            '지원기관',
                            '지원금액'
                           ])

# %%
for wo_list in trange(0,len(workers_list)):
    index = authors['교직원번호'].tolist().index(workers_list['교번'].loc[wo_list])
    research_list_0610.loc[wo_list] = [
                    workers_list['대학'].loc[wo_list], # 대학
                    workers_list['학과'].loc[wo_list], # 학과
                    workers_list['전공'].loc[wo_list], # 전공
                    workers_list['재직여부'].loc[wo_list], # 재직여부
                    workers_list['성명'].loc[wo_list], # 성명
                    workers_list['교번'].loc[wo_list], # 성명
                    workers_list['풀네임'].loc[wo_list], # 성명
        authors['AU-ID'].loc[index],
        workers_list['Year'].loc[wo_list], # 성명
        workers_list['Title'].loc[wo_list], # 성명
        workers_list['Source'].loc[wo_list], # 성명
        workers_list['Status'].loc[wo_list], # 성명
        workers_list['DB'].loc[wo_list], # 성명
        
        workers_list['논문구분'].loc[wo_list], # 성명
        workers_list['학술지색인'].loc[wo_list], # 성명
        workers_list['학진등재여부'].loc[wo_list], # 성명
        workers_list['학진등재후보'].loc[wo_list], # 성명
        
        workers_list['PNU-ID'].loc[wo_list], # 성명
        workers_list['DT(P)'].loc[wo_list], # 성명
        workers_list['DT(S)'].loc[wo_list], # 성명
        workers_list['DOI'].loc[wo_list], # 성명
        workers_list['EID'].loc[wo_list], # 성명
        workers_list['임용일자'].loc[wo_list], # 성명
        workers_list['퇴직일자'].loc[wo_list], # 성명
        
        workers_list['공동연구자수'].loc[wo_list], # 성명
        workers_list['권'].loc[wo_list], # 성명
        workers_list['호'].loc[wo_list], # 성명
        workers_list['페이지'].loc[wo_list], # 성명
        workers_list['ISSN'].loc[wo_list], # 성명
        workers_list['학술단체명'].loc[wo_list], # 성명
        workers_list['국내외구분'].loc[wo_list], # 성명
        workers_list['학문분야'].loc[wo_list], # 성명
        workers_list['연구원구분'].loc[wo_list], # 성명
        workers_list['책임구분'].loc[wo_list], # 성명
        workers_list['과제번호(차수)'].loc[wo_list], # 성명
        workers_list['과제번호'].loc[wo_list], # 성명
        workers_list['연구과제명'].loc[wo_list], # 성명
        workers_list['수행기관'].loc[wo_list], # 성명
        workers_list['지원기관'].loc[wo_list], # 성명
        workers_list['지원금액'].loc[wo_list], # 성명
        
        ]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-330e683cb42d> in <module>
#      44         workers_list['수행기관'].loc[wo_list], # 성명
#      45         workers_list['지원기관'].loc[wo_list], # 성명
# ---> 46         workers_list['지원금액'].loc[wo_list], # 성명
#      47
#      48                 ]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     668             key = com.apply_if_callable(key, self.obj)
#     669         indexer = self._get_setitem_indexer(key)
# --> 670         self._setitem_with_indexer(indexer, value)
#     671
#     672     def _validate_key(self, key, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#     872
#     873             if missing:
# --> 874                 return self._setitem_with_indexer_missing(indexer, value)
#     875
#     876         # set
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer_missing(self, indexer, value)
#    1120                 value = Series(value, index=self.obj.columns, name=indexer)
#    1121
# -> 1122             self.obj._data = self.obj.append(value)._data
#    1123             self.obj._maybe_update_cacher(clear=True)
#    1124             return self.obj
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7083             ignore_index=ignore_index,
#    7084             verify_integrity=verify_integrity,
# -> 7085             sort=sort,
#    7086         )
#    7087
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     282     )
#     283
# --> 284     return op.get_result()
#     285
#     286
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in get_result(self)
#     495
#     496             new_data = concatenate_block_managers(
# --> 497                 mgrs_indexers, self.new_axes, concat_axis=self.axis, copy=self.copy
#     498             )
#     499             if not self.copy:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#    2014                 values = values.view()
#    2015             b = b.make_block_same_class(values, placement=placement)
# -> 2016         elif is_uniform_join_units(join_units):
#    2017             b = join_units[0].block.concat_same_type(
#    2018                 [ju.block for ju in join_units], placement=placement
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\concat.py in is_uniform_join_units(join_units)
#     386         # no blocks that would get missing values (can lead to type upcasts)
#     387         # unless we're an extension dtype.
# --> 388         all(not ju.is_na or ju.block.is_extension for ju in join_units)
#     389         and
#     390         # no blocks with indexers (as then the dimensions do not fit)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\concat.py in <genexpr>(.0)
#     386         # no blocks that would get missing values (can lead to type upcasts)
#     387         # unless we're an extension dtype.
# --> 388         all(not ju.is_na or ju.block.is_extension for ju in join_units)
#     389         and
#     390         # no blocks with indexers (as then the dimensions do not fit)
#
# pandas\_libs\properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\concat.py in is_na(self)
#     166         chunk_len = max(total_len // 40, 1000)
#     167         for i in range(0, total_len, chunk_len):
# --> 168             if not isna(values_flat[i : i + chunk_len]).all():
#     169                 return False
#     170
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py in isna(obj)
#     124     Name: 1, dtype: bool
#     125     """
# --> 126     return _isna(obj)
#     127
#     128
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py in _isna_new(obj)
#     150         ),
#     151     ):
# --> 152         return _isna_ndarraylike(obj)
#     153     elif isinstance(obj, ABCGeneric):
#     154         return obj._constructor(obj._data.isna(func=isna))
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py in _isna_ndarraylike(obj)
#     254             result = np.empty(shape, dtype=bool)
#     255             vec = libmissing.isnaobj(values.ravel())
# --> 256             result[...] = vec.reshape(shape)
#     257
#     258     elif needs_i8_conversion(dtype):
#
# KeyboardInterrupt:
