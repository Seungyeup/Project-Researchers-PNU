# %%
import math
import pandas as pd
from pandas import DataFrame as df
from elsapy.elsclient import ElsClient
from elsapy.elsprofile import ElsAuthor, ElsAffil
from elsapy.elsdoc import FullDoc, AbsDoc
from elsapy.elssearch import ElsSearch
import json

researchers = pd.read_excel("저자리스트.xlsx")
scopus_all = df(columns=['성명','교직원번호','AU-ID','논문제목','논문타입','EID','Source'])

# api-key
# institue-key miss

con_file = open("config.json")
config = json.load(con_file)
con_file.close()

# key-client
client = ElsClient(config['apikey'])

# %%
prev=0
for pro in range(0,len(researchers)):
    au_id_num=researchers['AU-ID'].loc[pro]
    name = researchers['성명'].loc[pro]
    gyo = researchers['교직원번호'].loc[pro]
    if math.isnan(au_id_num):
        continue
    au_id = "au-id("+str(int(au_id_num))+")"
    tmp_search = ElsSearch(au_id,"scopus")
    tmp_search.execute(client)
    tmp_result = tmp_search.results_df
    result = tmp_result['dc:title']
    for doc_num in range(0,len(result)):
        scopus_all.loc[prev] = [
                                        name,
                                        gyo,
                                        au_id,
                                        tmp_result['dc:title'].loc[doc_num],
                                        tmp_result['prism:aggregationType'].loc[doc_num],
                                        tmp_result['eid'].loc[doc_num],
                                        tmp_result['prism:publicationName'].loc[doc_num]
                                  ]
        prev += 1

# %%
scopus_all
# Out:
#       성명                                               논문제목     논문타입  \
# 0    강점순  Phytohormone profiles of ‘Seolhyang’ and ‘Maeh...  Journal
# 1    강점순  Development of an SNP set for marker-assisted ...  Journal
# 2    강점순  Non-destructive evaluation of bacteria-infecte...  Journal
# 3    강점순  Characterization of the Lsi1 homologs in Cucur...  Journal
# 4    강점순  Regional differences in onion bulb quality and...  Journal
# ..   ...                                                ...      ...
# 883  정헌식  Browning characteristics of fresh-cut 'Tsugaru...  Journal
# 884  이상학  Quantitative evaluation of therapeutic effect ...  Journal
# 885  이상학  Selenium significantly inhibits adipocyte hype...  Journal
# 886  이상학  UV radiation-induced skin aging in hairless mi...  Journal
# 887  조재환  Measuring the willingness-to-pay for a horticu...  Journal
#
#                     EID                                             Source
# 0    2-s2.0-85081597572         Horticulture Environment and Biotechnology
# 1    2-s2.0-85054981027                     Journal of Plant Biotechnology
# 2    2-s2.0-85010928575     Journal of the Science of Food and Agriculture
# 3    2-s2.0-85027246280  Korean Journal of Horticultural Science and Te...
# 4    2-s2.0-85042867114               Horticultural Science and Technology
# ..                  ...                                                ...
# 883  2-s2.0-60249083913                                     Food Chemistry
# 884  2-s2.0-84880299255                       Journal of Ethnopharmacology
# 885  2-s2.0-84870722724                  Biological Trace Element Research
# 886  2-s2.0-84863546775        International Journal of Molecular Medicine
# 887  2-s2.0-52449090979                                        HortScience
#
# [888 rows x 5 columns]

# %%
scopus_all.to_excel("DB/SCOPUS/scopus_all.xlsx")
