# %%
import math
import pandas as pd
from pandas import DataFrame as df
from elsapy.elsclient import ElsClient
from elsapy.elsprofile import ElsAuthor, ElsAffil
from elsapy.elsdoc import FullDoc, AbsDoc
from elsapy.elssearch import ElsSearch
import json

researchers = pd.read_excel("저자test1.xlsx")
scopus_all = df(columns=['성명','AU-ID','논문제목'])

# api-key
# institue-key miss

con_file = open("config.json")
config = json.load(con_file)
con_file.close()

# key-client
client = ElsClient(config['apikey'])

# %%
prev=0
for pro in range(0,len(researchers)):
    au_id_num=researchers['S_ID_1'].loc[pro]
    if math.isnan(au_id_num):
        continue
    au_id = "au-id("+str(int(au_id_num))+")"
    tmp_search = ElsSearch(au_id,"scopus")
    tmp_search.execute(client)
    tmp_result = tmp_search.results_df
    result = tmp_result['dc:title']
    for doc_num in range(0,len(result)):
        scopus_all.loc[prev+doc_num] = [
                                      researchers['성명'].loc[pro],
                                      researchers['S_ID_1'].loc[pro],
                                      result.loc[doc_num]
                                  ]
        prev += 1

# %%
scopus_all.to_excel("temp_scopus_all.xlsx")

# %%
scopus_all
# Out:
#       성명         AU-ID                                               논문제목
# 0    강한석  1.403587e+10  Proteomic analysis reveals PGAM1 altering cis-...
# 2    강한석  1.403587e+10  Association of protein expression in isolated ...
# 4    강한석  1.403587e+10  Comparative studies on derivatization methods ...
# 6    강한석  1.403587e+10  Myoglobin: A promising exogenous reference mar...
# 8    강한석  1.403587e+10  Effects of lactation stage and individual perf...
# ..   ...           ...                                                ...
# 261  김명후  3.661175e+10  Retinoic acid promotes the development of Arg1...
# 263  김명후  3.661175e+10  Effects of synchronicity of carbohydrate and p...
# 265  김명후  3.661175e+10  Short-chain fatty acids activate GPR41 and GPR...
# 267  김명후  3.661175e+10  The effects of fermented soybean meal on immun...
# 269  김명후  3.661175e+10  The stress of weaning influences serum levels ...
#
# [220 rows x 3 columns]
