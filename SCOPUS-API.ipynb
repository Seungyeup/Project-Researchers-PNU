# %%
# !pip install elsapy
# Out:
# Requirement already satisfied: elsapy in c:\users\user\anaconda3\lib\site-packages (0.5.0)
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (from elsapy) (2.22.0)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests->elsapy) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\user\anaconda3\lib\site-packages (from requests->elsapy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests->elsapy) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests->elsapy) (2019.11.28)

# %%
from elsapy.elsclient import ElsClient
from elsapy.elsprofile import ElsAuthor, ElsAffil
from elsapy.elsdoc import FullDoc, AbsDoc
from elsapy.elssearch import ElsSearch
import json

# api-key
# institue-key miss

con_file = open("config.json")
config = json.load(con_file)
con_file.close()

# key-client
client = ElsClient(config['apikey'])

# %%
my_auth = ElsAuthor(
        uri = 'https://api.elsevier.com/content/author/author_id/6601972916')
# Read author data, then write to disk
if my_auth.read(client):
    print ("my_auth.full_name: ", my_auth.full_name)
    my_auth.write()
else:
    print ("Read author failed.")
# Out:
# my_auth.full_name:  Kwangseuk Kyhm

# %%
search =  ElsSearch("au-id(6601972916)",'scopus')
search.execute(client)

# %%
search.results_df
# Out:
#     @_fa                                               link  \
# 0   true  {'self': 'https://api.elsevier.com/content/abs...
# 1   true  {'self': 'https://api.elsevier.com/content/abs...
# 2   true  {'self': 'https://api.elsevier.com/content/abs...
# 3   true  {'self': 'https://api.elsevier.com/content/abs...
# 4   true  {'self': 'https://api.elsevier.com/content/abs...
# 5   true  {'self': 'https://api.elsevier.com/content/abs...
# 6   true  {'self': 'https://api.elsevier.com/content/abs...
# 7   true  {'self': 'https://api.elsevier.com/content/abs...
# 8   true  {'self': 'https://api.elsevier.com/content/abs...
# 9   true  {'self': 'https://api.elsevier.com/content/abs...
# 10  true  {'self': 'https://api.elsevier.com/content/abs...
# 11  true  {'self': 'https://api.elsevier.com/content/abs...
# 12  true  {'self': 'https://api.elsevier.com/content/abs...
# 13  true  {'self': 'https://api.elsevier.com/content/abs...
# 14  true  {'self': 'https://api.elsevier.com/content/abs...
# 15  true  {'self': 'https://api.elsevier.com/content/abs...
# 16  true  {'self': 'https://api.elsevier.com/content/abs...
# 17  true  {'self': 'https://api.elsevier.com/content/abs...
# 18  true  {'self': 'https://api.elsevier.com/content/abs...
# 19  true  {'self': 'https://api.elsevier.com/content/abs...
# 20  true  {'self': 'https://api.elsevier.com/content/abs...
# 21  true  {'self': 'https://api.elsevier.com/content/abs...
# 22  true  {'self': 'https://api.elsevier.com/content/abs...
# 23  true  {'self': 'https://api.elsevier.com/content/abs...
# 24  true  {'self': 'https://api.elsevier.com/content/abs...
#
#                                             prism:url          dc:identifier  \
# 0   https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85060527926
# 1   https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85072696043
# 2   https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85070391832
# 3   https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85062368510
# 4   https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85069493415
# 5   https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85055204629
# 6   https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85053887609
# 7   https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85053011729
# 8   https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85051644828
# 9   https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85047916803
# 10  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85069523128
# 11  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85052878058
# 12  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85034446003
# 13  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85034862074
# 14  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85026797404
# 15  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:84987942293
# 16  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85029685513
# 17  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85008391614
# 18  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85006511425
# 19  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:84957843833
# 20  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:84957590944
# 21  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:84962788651
# 22  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:84930965872
# 23  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:84938704414
# 24  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:84938521958
#
#                    eid                                           dc:title  \
# 0   2-s2.0-85060527926  Intermolecular distance measurement with TNT s...
# 1   2-s2.0-85072696043        Stimulation emission depleted photoacoustic
# 2   2-s2.0-85070391832  Two-step energy transfer dynamics in conjugate...
# 3   2-s2.0-85062368510  Optical gain of inelastic exciton-exciton scat...
# 4   2-s2.0-85069493415  Shape ellipticity dependence of exciton fine l...
# 5   2-s2.0-85055204629  Modeling Quantum Beats by Degenerate Four-Wave...
# 6   2-s2.0-85053887609  Light Controlled Optical Aharonov-Bohm Oscilla...
# 7   2-s2.0-85053011729  Decoherence Dynamics of Localized States in a ...
# 8   2-s2.0-85051644828  Carrier Relaxation Dynamics Between Localized ...
# 9   2-s2.0-85047916803  Magnetic field insensitive photoluminescence d...
# 10  2-s2.0-85069523128  Two-dimensional nature of center-of-mass excit...
# 11  2-s2.0-85052878058  Optical Aharonov-Bohm Oscillations with Disord...
# 12  2-s2.0-85034446003  Excitation polarization dependence of optical ...
# 13  2-s2.0-85034862074  Surface plasmon-assisted photoluminescence enh...
# 14  2-s2.0-85026797404  Optical sectioning in optical resolution photo...
# 15  2-s2.0-84987942293  Inhibitor effects on molecular beacon-based me...
# 16  2-s2.0-85029685513  All-optical polarization phase modulation in c...
# 17  2-s2.0-85008391614  Quasi-one-dimensional density of states in a s...
# 18  2-s2.0-85006511425  Exciton Dipole-Dipole Interaction in a Single ...
# 19  2-s2.0-84957843833  Enhancement of the photoluminescence propertie...
# 20  2-s2.0-84957590944  Observation of a Biexciton Wigner Molecule by ...
# 21  2-s2.0-84962788651  Polarization dependence and optical Aharonov-B...
# 22  2-s2.0-84930965872  Photosensitization of novel ruthenium-function...
# 23  2-s2.0-84938704414  Solvent-modified ultrafast decay dynamics in c...
# 24  2-s2.0-84938521958  Polarization anisotropy of exciton in self-ass...
#
#    dc:creator                              prism:publicationName prism:eIssn  \
# 0      Kim I.                                 Scientific Reports    20452322
# 1     Park S.                                     Optics Express    10944087
# 2      Kim I.                                           Polymers    20734360
# 3     Jang J.                            Applied Physics Letters         NaN
# 4     Yang H.                       Current Optics and Photonics    25087274
# 5       Je K.     Physica Status Solidi - Rapid Research Letters    18626270
# 6      Kim H.                                       Nano Letters    15306992
# 7      Kim M.     Physica Status Solidi - Rapid Research Letters    18626270
# 8     Park S.             Journal of the Korean Physical Society    19768524
# 9      Lee W.                Japanese Journal of Applied Physics    13474065
# 10     Lee W.                       Current Optics and Photonics    25087274
# 11    Kyhm K.                         NanoScience and Technology         NaN
# 12     Kim H.              Journal of Physics: Conference Series    17426596
# 13     Kim I.             Molecular Crystals and Liquid Crystals    15635287
# 14    Park S.                                     Optics Express    10944087
# 15      Le V.                 Sensors and Actuators, B: Chemical         NaN
# 16      Je K.                       Current Optics and Photonics    25087274
# 17     Kim H.                                 Scientific Reports    20452322
# 18     Kim H.                                       Nano Letters    15306992
# 19    Wang S.  Journal of Materials Science: Materials in Ele...    1573482X
# 20     Kim H.                                       Nano Letters    15306992
# 21  Park S.H.  2015 11th Conference on Lasers and Electro-Opt...         NaN
# 22    Moon J.  Journal of Photochemistry and Photobiology A: ...         NaN
# 23     Kim I.  Progress in Biomedical Optics and Imaging - Pr...         NaN
# 24     Kim I.                            Current Applied Physics         NaN
#
#    prism:volume  ...  prism:aggregationType subtype subtypeDescription  \
# 0             9  ...                Journal      ar            Article
# 1            27  ...                Journal      ar            Article
# 2            11  ...                Journal      ar            Article
# 3           114  ...                Journal      ar            Article
# 4             3  ...                Journal      ar            Article
# 5            13  ...                Journal      ar            Article
# 6            18  ...                Journal      ar            Article
# 7            12  ...                Journal      ar            Article
# 8            73  ...                Journal      ar            Article
# 9            57  ...                Journal      cp   Conference Paper
# 10            2  ...                Journal      ar            Article
# 11          NaN  ...            Book Series      ch            Chapter
# 12          906  ...  Conference Proceeding      cp   Conference Paper
# 13          654  ...                Journal      ar            Article
# 14           25  ...                Journal      ar            Article
# 15          240  ...                Journal      ar            Article
# 16            1  ...                Journal      ar            Article
# 17            7  ...                Journal      ar            Article
# 18           16  ...                Journal      ar            Article
# 19           27  ...                Journal      ar            Article
# 20           16  ...                Journal      ar            Article
# 21            3  ...  Conference Proceeding      cp   Conference Paper
# 22          310  ...                Journal      ar            Article
# 23         9523  ...  Conference Proceeding      cp   Conference Paper
# 24           15  ...                Journal      ar            Article
#
#    article-number    source-id  openaccess openaccessFlag prism:issn  \
# 0             496  21100200805           1           True        NaN
# 1             NaN        12862           0          False        NaN
# 2            1206        54222           1           True        NaN
# 3          081101        27030           0          False   00036951
# 4             NaN  21100831043           0          False   25087266
# 5         1800354  10400153302           1           True   18626254
# 6             NaN        17853           0          False   15306984
# 7         1800176  10400153302           0          False   18626254
# 8             NaN        28637           0          False   03744884
# 9          06HE06       130262           0          False   00214922
# 10            NaN  21100831043           0          False   25087266
# 11            NaN  21100216986           0          False   14344904
# 12         012006       130053           1           True   17426588
# 13            NaN        24711           0          False   15421406
# 14            NaN        12862           0          False        NaN
# 15            NaN        25236           0          False   09254005
# 16            NaN  21100831043           1           True   25087266
# 17          40026  21100200805           1           True        NaN
# 18            NaN        17853           0          False   15306984
# 19            NaN        21177           0          False   09574522
# 20            NaN        17853           0          False   15306984
# 21        7376565  21100455482           0          False        NaN
# 22            NaN        26966           0          False   10106030
# 23         95230N       130022           0          False   16057422
# 24            NaN        27477           0          False   15671739
#
#                   pii                                prism:isbn
# 0                 NaN                                       NaN
# 1                 NaN                                       NaN
# 2                 NaN                                       NaN
# 3                 NaN                                       NaN
# 4                 NaN                                       NaN
# 5                 NaN                                       NaN
# 6                 NaN                                       NaN
# 7                 NaN                                       NaN
# 8                 NaN                                       NaN
# 9                 NaN                                       NaN
# 10                NaN                                       NaN
# 11                NaN                                       NaN
# 12                NaN                                       NaN
# 13                NaN                                       NaN
# 14                NaN                                       NaN
# 15  S0925400516314514                                       NaN
# 16                NaN                                       NaN
# 17          srep40026                                       NaN
# 18                NaN                                       NaN
# 19                NaN                                       NaN
# 20                NaN                                       NaN
# 21                NaN  [{'@_fa': 'true', '$': '9781467371094'}]
# 22  S1010603015001975                                       NaN
# 23                NaN  [{'@_fa': 'true', '$': '9781628416794'}]
# 24  S1567173915000796                                       NaN
#
# [25 rows x 28 columns]
